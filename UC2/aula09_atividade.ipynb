# %%
import pandas as pd
import numpy as np
import random

# %%
amostra=[random.randint(1,99)for _ in range(50)]
print(amostra)
dados=np.array(amostra)
print(dados)
# Out:
# [57, 38, 75, 99, 12, 80, 43, 39, 66, 73, 38, 48, 30, 66, 87, 75, 87, 65, 9, 71, 70, 24, 59, 59, 85, 24, 60, 99, 27, 97, 10, 79, 35, 47, 63, 37, 58, 75, 78, 85, 95, 64, 53, 79, 96, 13, 96, 17, 29, 48]
# [57 38 75 99 12 80 43 39 66 73 38 48 30 66 87 75 87 65  9 71 70 24 59 59
#  85 24 60 99 27 97 10 79 35 47 63 37 58 75 78 85 95 64 53 79 96 13 96 17
#  29 48]

# %%
amostra_df=pd.DataFrame(amostra,columns=['valores'])
print(amostra_df)
# Out:
#     valores
# 0        57
# 1        38
# 2        75
# 3        99
# 4        12
# 5        80
# 6        43
# 7        39
# 8        66
# 9        73
# 10       38
# 11       48
# 12       30
# 13       66
# 14       87
# 15       75
# 16       87
# 17       65
# 18        9
# 19       71
# 20       70
# 21       24
# 22       59
# 23       59
# 24       85
# 25       24
# 26       60
# 27       99
# 28       27
# 29       97
# 30       10
# 31       79
# 32       35
# 33       47
# 34       63
# 35       37
# 36       58
# 37       75
# 38       78
# 39       85
# 40       95
# 41       64
# 42       53
# 43       79
# 44       96
# 45       13
# 46       96
# 47       17
# 48       29
# 49       48

# %%
valor_maximo=amostra_df['valores'].max()
valor_minimo=amostra_df['valores'].min()
amplitude_total=valor_maximo-valor_minimo

print(f'Menor valor:{valor_minimo}')
print(f'maior valor:{valor_maximo}')
print(f'amplitude:{valor_maximo}')
# Out:
# Menor valor:9
# maior valor:99
# amplitude:99

# %%
import matplotlib.pyplot as plt
#configuraçao do painel
fig,ax=plt.subplots(1,2,figsize=(12,6))

#Boxplot
ax[0].boxplot(amostra_df['valores'])
ax[0].set_title('distribuição de dados - Boxplot')
ax[0].set_ylabel('valores')

#exibindo as medidas
ax[1].text(0.1,0.8,f"menor valor:{valor_minimo}")
ax[1].text(0.1,0.7,f"maior valor:{valor_maximo}")
ax[1].text(0.1,0.6,f"menor valor:{amplitude_total}")
ax[1].set_axis_off()

plt.tight_layout()
plt.show()
